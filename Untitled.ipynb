# %%
import pandas as pd
df_artist=pd.read_csv('artists.csv')
df_artist.sort_values(by='popularity',ascending=False).head(200)

df_artist
# Out:
#                              id  followers                 genres  \
# 0        0DheY5irMjBUeLybbCUEZ2        0.0                     []
# 1        0DlhY15l3wsrnlfGio2bjU        5.0                     []
# 2        0DmRESX2JknGPQyO15yxg7        0.0                     []
# 3        0DmhnbHjm1qw6NCYPeZNgJ        0.0                     []
# 4        0Dn11fWM7vHQ3rinvWEl4E        2.0                     []
# ...                         ...        ...                    ...
# 1104344  6rJIG42vcWAf1UBdRFlQxB     3345.0                     []
# 1104345  1ljurfXKPlGncNdW3J8zJ8     2123.0  ['deep acoustic pop']
# 1104346  2vnT9YhKIvjVo9LnVjWmr2       26.0                     []
# 1104347  3ID0E5XCvnJIYZEq043ZoB      406.0                     []
# 1104348  5m0Y4WSYyai2BU752lCASy      146.0                     []
#
#                                                    name  popularity
# 0        Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# ...

# %%
df_data_by_artist=pd.read_csv('data_by_artist_o.csv')
new_columns=['artists','genres','danceability','duration_ms','popularity']
df_data_by_artist_edit=df_data_by_artist[new_columns]
df_data_by_artist_edit.head()
df_data_by_artist_edit['popularity'].value_counts().to_frame().reset_index().sort_values('index')
# Out:
#           index  popularity
# 0      0.000000        4368
# 4157   0.009709           1
# 1143   0.009804           2
# 2105   0.011407           1
# 4079   0.012579           1
# ...         ...         ...
# 658   88.000000           3
# 3205  89.000000           1
# 1400  90.000000           1
# 4043  92.000000           1
# 4436  93.000000           1
#
# [4663 rows x 2 columns]

# %%
df_data_o
new_columns_data_o=['artists','danceability','duration_ms','popularity']
df_data_o_edit=df_data_o[new_columns_data_o]
df_data_o_edit.head()
df_data_o_edit['popularity'].value_counts()
# Out:
# 0      27892
# 43      3136
# 44      3117
# 41      3078
# 42      3051
#        ...
# 95         4
# 96         4
# 97         1
# 99         1
# 100        1
# Name: popularity, Length: 100, dtype: int64

# %%
df_data_o=pd.read_csv('data_o.csv')
newest=df_data_o.sort_values(by='year',ascending=False)
# Out:
#         valence  year  acousticness                                   artists  \
# 170652    0.642  2020        0.1320                     ['KEVVO', 'J Balvin']
# 19608     0.357  2020        0.0194        ['Cardi B', 'Megan Thee Stallion']
# 19606     0.756  2020        0.2210                 ['24kGoldn', 'iann dior']
# 75038     0.638  2020        0.1600                    ['Joji', 'Lil Yachty']
# 75039     0.557  2020        0.0919                                ['Polo G']
# ...         ...   ...           ...                                       ...
# 75072     0.350  2020        0.5360                            ['Jhené Aiko']
# 75073     0.414  2020        0.1980                             ['Baby Keem']
# 75074     0.611  2020        0.0641                        ['Princess Nokia']
# 75075     0.764  2020        0.0547  ['Freddie Gibbs', 'Hit-Boy', 'Big Sean']
# 75076     0.430  2020        0.2030                 ['iann dior', 'Lil Baby']
#
# ...

# %%
df_year=pd.read_csv('data_by_year_o.csv')
df_year.sort_val(by='year',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-614dd625d4ad> in <module>
#       1 df_year=pd.read_csv('data_by_year_o.csv')
# ----> 2 df_year(by='year',ascending=False)
#
# TypeError: 'DataFrame' object is not callable

# %%
df_genres=pd.read_csv('data_by_genres_o.csv')
df_genres[df_genres['genres']=='pop']
# Out:
#       mode genres  acousticness  danceability    duration_ms    energy  \
# 2170     1    pop      0.276873      0.628349  216336.259142  0.611041
#
#       instrumentalness  liveness  loudness  speechiness       tempo   valence  \
# 2170          0.025298  0.175073 -6.977413     0.085784  119.649666  0.479474
#
#       popularity  key
# 2170   60.745909    1

# %%
df_genres=pd.read_csv('data_by_genres_o.csv')
